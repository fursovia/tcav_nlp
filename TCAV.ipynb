# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np

# %%
def plot_graphs(scores):
    fig, axes = plt.subplots(len(scores.keys()), 1, figsize=(30, 30))

    for i, (key, val) in enumerate(scores.items()):
        labs = [key for key, val in scores[key].items()]
        vals = [val for key, val in scores[key].items()]

        axes[i].bar(labs,
                    vals,
                    alpha=0.3,
                    color='b',
                    label='TCAV',
                    width=0.2)

        axes[i].set_title(f'TCAV for "{key}" concept', size=25)
        axes[i].set_xlabel('Labels', size=25)
        axes[i].set_ylabel('TCAV', size=25)
        axes[i].set_xticklabels(labs, rotation='vertical')
        axes[i].legend(prop={'size': 15})
        axes[i].tick_params(labelsize=20)

    fig.tight_layout()
    plt.show()

# %% [markdown]
# Here we test three concepts "Москва", "Ученые" and "Концерт" using trigrams. See examples below.

# %%
concepts = pickle.load(open('experiments/test/concepts.pkl', 'rb'))

# %%
for key in concepts.keys():
    print(f'10 positive examples for "{key}" concept:\n')
    print('\n'.join(concepts[key]['pos'][:10]))
    print(f'\n10 negative examples for "{key}" concept:\n')
    print('\n'.join(concepts[key]['neg'][:10]))
    print('-' * 50, '\n')
# Out:
# 10 positive examples for "москва" concept:
#
# в центр москва
# в москва задерживать
# в москва и
# в москва открываться
# в москва на
# квартира в москва
# на восток москва
# в москва убивать
# в москва появляться
# в москва в
#
# 10 negative examples for "москва" concept:
#
# агентство fitch начинать
# рассмешить портрет николай
# о наказание за
# в татнефть опровергать
# травля цукерберг из
# шварценеггер извиняться перед
# забеременеть дженнифер гарнер
# sony в компания
# журналист в отпуск
# в общепит гигантский
# --------------------------------------------------
#
# 10 positive examples for "ученые" concept:
#
# ученый рассказывать о
# китайский ученый создавать
# ученый расшифровывать ген
# ученый находить способ
# ученый придумывать самый
# лишать ученый степень
# ученый обнаруживать у
# получать ученый степень
# ученый степень мединский
# ученый создавать модель
#
# 10 negative examples for "ученые" concept:
#
# у гоголь центр
# сергей иванов пообещать
# дефицит бюджет фифа
# шойгу докладывать путин
# за неточный прогноз
# испытание в 2011
# курский вокзал электричка
# буданов устраивать скандал
# зверство украинский силовик
# бурятский изолятор заключенный
# --------------------------------------------------
#
# 10 positive examples for "концерт" concept:
#
# концерт в москва
# концерт из за
# давать концерт в
# отменять концерт на
# пройти концерт в
# концерт в честь
# отменять концерт в
# отменять концерт из
# отменять весь концерт
# в парижский концертный
#
# 10 negative examples for "концерт" concept:
#
# критик называть фауст
# порт зайти адмирал
# афганский власть просить
# в аргентина признавать
# вместо водка в
# уайнхаус пополняться новый
# пензенский епархия рпц
# литва решение калининградский
# памятник доброволец из
# и их соучастник
# --------------------------------------------------

# %% [markdown]
# ## Deep Averaging Network

# %%
dan_scores = pickle.load(open('experiments/dan/scores.pkl', 'rb'))

# %%
plot_graphs(dan_scores)

# %% [markdown]
# ## LSTM

# %%
lstm_scores = pickle.load(open('experiments/dan/scores.pkl', 'rb'))

# %%
plot_graphs(lstm_scores)

# %% [markdown]
# ## Additional concepts for DAN

# %%
test_scores = pickle.load(open('experiments/test/scores.pkl', 'rb'))

# %%
dan_scores(test_scores)
